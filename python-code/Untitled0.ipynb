# %%
import os
os.chdir('/content/drive/My Drive/Colab/Ear_Project')

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab/Ear_Project'

# %%
# !git clone https://github.com/davircarvalho/HRTF_individualization-.git
# Out:
# Cloning into 'HRTF_individualization-'...
# remote: Enumerating objects: 96, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 168 (delta 45), reused 5 (delta 1), pack-reused 72
# Receiving objects: 100% (168/168), 7.24 MiB | 12.58 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %%
cd HRTF_individualization-/
# Out:
# /content/drive/My Drive/Colab/Ear_Project/HRTF_individualization-
